# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
diabetes_df=pd.read_csv("diabetes.csv")

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
diabetes_df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI']]
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
# [768 rows x 5 columns]

# %%
diabetes_df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI']]=diabetes_df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI']].replace(0,np.NaN)

# %%
diabetes_df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
diabetes_df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
diabetes_df.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5e8ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5e48370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5df5790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5da1bb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5dd10d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5d8b3a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5d8b490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5d378e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fcae5d130d0>]],
#       dtype=object)

# %%
sns.pairplot(diabetes_df)

# %%
sns.heatmap(diabetes_df.corr(),annot=True)

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
X=diabetes_df[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y=diabetes_df["Outcome"]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 60             2     84.0            NaN            NaN      NaN   NaN
# 618            9    112.0           82.0           24.0      NaN  28.2
# 346            1    139.0           46.0           19.0     83.0  28.7
# 294            0    161.0           50.0            NaN      NaN  21.9
# 231            6    134.0           80.0           37.0    370.0  46.2
# ..           ...      ...            ...            ...      ...   ...
# 71             5    139.0           64.0           35.0    140.0  28.6
# 106            1     96.0          122.0            NaN      NaN  22.4
# 270           10    101.0           86.0           37.0      NaN  45.6
# 435            0    141.0            NaN            NaN      NaN  42.4
# 102            0    125.0           96.0            NaN      NaN  22.5
#
#      DiabetesPedigreeFunction  Age
# 60                      0.304   21
# 618                     1.282   50
# 346                     0.654   22
# 294                     0.254   65
# 231                     0.238   46
# ..                        ...  ...
# 71                      0.411   26
# 106                     0.207   27
# 270                     1.136   38
# 435                     0.205   29
# 102                     0.262   21
#
# [614 rows x 8 columns]

# %%
X_train.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                24
# SkinThickness               176
# Insulin                     290
# BMI                           7
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64

# %%
X_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 668            6     98.0           58.0           33.0    190.0  34.0
# 324            2    112.0           75.0           32.0      NaN  35.7
# 624            2    108.0           64.0            NaN      NaN  30.8
# 690            8    107.0           80.0            NaN      NaN  24.6
# 473            7    136.0           90.0            NaN      NaN  29.9
# ..           ...      ...            ...            ...      ...   ...
# 355            9    165.0           88.0            NaN      NaN  30.4
# 534            1     77.0           56.0           30.0     56.0  33.3
# 344            8     95.0           72.0            NaN      NaN  36.8
# 296            2    146.0           70.0           38.0    360.0  28.0
# 462            8     74.0           70.0           40.0     49.0  35.3
#
#      DiabetesPedigreeFunction  Age
# 668                     0.430   43
# 324                     0.148   21
# 624                     0.158   21
# 690                     0.856   34
# 473                     0.210   50
# ..                        ...  ...
# 355                     0.302   49
# 534                     1.251   24
# 344                     0.485   57
# 296                     0.337   29
# 462                     0.705   39
#
# [154 rows x 8 columns]

# %%
X_test.isnull().sum()
# Out:
# Pregnancies                  0
# Glucose                      0
# BloodPressure               11
# SkinThickness               51
# Insulin                     84
# BMI                          4
# DiabetesPedigreeFunction     0
# Age                          0
# dtype: int64

# %%
columns_with_nan=["Glucose","BloodPressure","SkinThickness","Insulin","BMI"]

fig,ax=plt.subplots(nrows=1,ncols=5,figsize=(20,5))
for i in range(len(columns_with_nan)):
   sns.displot(X_train[columns_with_nan[i]],ax=ax[i])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
X_train.loc[:,"Glucose"]
# Out:
# 60      84.0
# 618    112.0
# 346    139.0
# 294    161.0
# 231    134.0
#        ...
# 71     139.0
# 106     96.0
# 270    101.0
# 435    141.0
# 102    125.0
# Name: Glucose, Length: 614, dtype: float64

# %%
Glucose_mean_xtrain=X_train.loc[:,"Glucose"].mean()

# %%
BloodPressure_mean_xtrain=X_train.loc[:,"BloodPressure"].mean()

# %%
SkinThickness_median_xtrain=X_train.loc[:,"SkinThickness"].median()
Insulin_median_xtrain=X_train.loc[:,"Insulin"].median()
BMI_median_xtrain=X_train.loc[:,"BMI"].median()

# %%
X_train.loc[:,"Glucose"]=X_train.loc[:,"Glucose"].fillna(Glucose_mean_xtrain)
X_train.loc[:,"BloodPressure"]=X_train.loc[:,"BloodPressure"].fillna(BloodPressure_mean_xtrain)
X_train.loc[:,"SkinThickness"]=X_train.loc[:,"SkinThickness"].fillna(SkinThickness_median_xtrain)
X_train.loc[:,"Insulin"]=X_train.loc[:,"Insulin"].fillna(Insulin_median_xtrain)
X_train.loc[:,"BMI"]=X_train.loc[:,"BMI"].fillna(BMI_median_xtrain)

# %%
X_train.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
X_test.loc[:,"Glucose"]=X_test.loc[:,"Glucose"].fillna(Glucose_mean_xtrain)
X_test.loc[:,"BloodPressure"]=X_test.loc[:,"BloodPressure"].fillna(BloodPressure_mean_xtrain)
X_test.loc[:,"SkinThickness"]=X_test.loc[:,"SkinThickness"].fillna(SkinThickness_median_xtrain)
X_test.loc[:,"Insulin"]=X_test.loc[:,"Insulin"].fillna(Insulin_median_xtrain)
X_test.loc[:,"BMI"]=X_test.loc[:,"BMI"].fillna(BMI_median_xtrain)

# %%
X_test.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 60             2     84.0     121.847291     121.847291  121.847291
# 618            9    112.0      82.000000      24.000000  121.847291
# 346            1    139.0      46.000000      19.000000   83.000000
# 294            0    161.0      50.000000     121.847291  121.847291
# 231            6    134.0      80.000000      37.000000  370.000000
# ..           ...      ...            ...            ...         ...
# 71             5    139.0      64.000000      35.000000  140.000000
# 106            1     96.0     122.000000     121.847291  121.847291
# 270           10    101.0      86.000000      37.000000  121.847291
# 435            0    141.0     121.847291     121.847291  121.847291
# 102            0    125.0      96.000000     121.847291  121.847291
#
#             BMI  DiabetesPedigreeFunction  Age
# 60   121.847291                     0.304   21
# 618   28.200000                     1.282   50
# 346   28.700000                     0.654   22
# 294   21.900000                     0.254   65
# 231   46.200000                     0.238   46
# ..          ...                       ...  ...
# 71    28.600000                     0.411   26
# 106   22.400000                     0.207   27
# 270   45.600000                     1.136   38
# 435   42.400000                     0.205   29
# 102   22.500000                     0.262   21
#
# [614 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler=MinMaxScaler()

# %%
X_train=min_max_scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[0.11764706, 0.25806452, 0.99844174, ..., 1.        , 0.09649872,
#         0.        ],
#        [0.52941176, 0.43870968, 0.59183673, ..., 0.09648106, 0.51409052,
#         0.48333333],
#        [0.05882353, 0.61290323, 0.2244898 , ..., 0.10130511, 0.24594364,
#         0.01666667],
#        ...,
#        [0.58823529, 0.36774194, 0.63265306, ..., 0.26435809, 0.45175064,
#         0.28333333],
#        [0.        , 0.62580645, 0.99844174, ..., 0.23348415, 0.05422716,
#         0.13333333],
#        [0.        , 0.52258065, 0.73469388, ..., 0.04148685, 0.07856533,
#         0.        ]])

# %%
X_test=min_max_scaler.transform(X_test)

# %%
X_test
# Out:
# array([[0.35294118, 0.3483871 , 0.34693878, ..., 0.15244007, 0.15029889,
#         0.36666667],
#        [0.11764706, 0.43870968, 0.52040816, ..., 0.16884185, 0.02988898,
#         0.        ],
#        [0.11764706, 0.41290323, 0.40816327, ..., 0.12156613, 0.03415884,
#         0.        ],
#        ...,
#        [0.47058824, 0.32903226, 0.48979592, ..., 0.17945476, 0.17378309,
#         0.6       ],
#        [0.11764706, 0.65806452, 0.46938776, ..., 0.09455143, 0.11058924,
#         0.13333333],
#        [0.47058824, 0.19354839, 0.46938776, ..., 0.1649826 , 0.2677199 ,
#         0.3       ]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model=KNeighborsClassifier(10)

# %%
knn_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred=knn_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7727272727272727

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84        99
#            1       0.76      0.53      0.62        55
#
#     accuracy                           0.77       154
#    macro avg       0.77      0.72      0.73       154
# weighted avg       0.77      0.77      0.76       154

# %%
knn_model.predict(np.array([[9,112.0,82.000000,24.000000,121.847291,28.200000,1.282,50]]))
# Out:
# array([1])
